# %%
import numpy as np
import pandas as pd
from datetime import *

import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor

from sklearn.metrics import r2_score

import pylab as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing

print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# ## Get data

# %%
with open('steps.dat', 'r') as handle:
    steps = handle.readline().strip().split()
steps_ = [f's{i}' for i in range(len(steps))]

# %%
df = pd.read_csv(
    'combined_data_step_7.csv',
    dtype={'fips': str}).set_index('fips')
df.rename(columns={a: b for a, b in zip(steps, steps_)}, inplace=True)
df.head()
# Out:
#        65yrs  minority  black  hispanic  population  perc_65yrs  \
# fips
# 01001   8924     13262  11237      1671       55869    0.159731
# 01003  46830     28036  19593     10534      223234    0.209780
# 01005   4861     12552  11906      1117       24686    0.196913
# 01007   3733      5203   4763       623       22394    0.166696
# 01009  10814      2414    978      5582       57826    0.187009
#
#        perc_minority  perc_black  perc_hispanic  poverty  ...    s21    s22  \
# fips                                                      ...
# 01001       0.237377    0.201131       0.029909     7587  ...   45.0   62.0
# 01003       0.125590    0.087769       0.047188    21069  ...  270.0  235.0
# 01005       0.508466    0.482298       0.045248     6788  ...   -2.0   -8.0
# 01007       0.232339    0.212691       0.027820     4400  ...   20.0   27.0
# 01009       0.041746    0.016913       0.096531     7527  ...   73.0   58.0
#
#          s23    s24    s25    s26    s27    s28    s29  covid
# fips
# 01001   61.0  241.0   91.0   54.0   80.0   85.0   65.0   2126
# 01003  210.0  295.0  430.0  571.0  142.0  160.0  287.0   6768
# 01005    4.0  210.0   52.0   39.0   21.0   35.0   54.0   1055
# 01007   26.0   52.0   26.0   24.0   48.0   49.0   53.0    861
# 01009   52.0  428.0   69.0   44.0   49.0  103.0  118.0   2009
#
# [5 rows x 47 columns]

# %%
steps_vec = [x.split('-') for x in steps]
steps = [f'2020-{m.zfill(2)}-{d.zfill(2)}' for m, d in steps_vec]

last = datetime.strptime(steps[-1], '%Y-%m-%d')
next_1 = (last + timedelta(days=1)).date()
next_2 = (last + timedelta(days=1)).date()

# %%
df['urban_risk'] = df['perc_urban_pop'] * (df['risk_flu'] - df['risk_flu'].min())
covariates = [
    'population', 
    'perc_65yrs', 
    'perc_minority', 
    'perc_black', 
    'perc_hispanic', 
    'perc_poverty', 
    'perc_urban_pop',
    'income',
    'risk', 
    'risk_flu',
    'urban_risk'
]

df_z = df[steps_].copy()
for c in covariates:
    mean, std = df[c].mean(), df[c].std()
    df_z[c] = (df[c] - mean) / std
df_z.head()
# Out:
#        s0    s1    s2    s3    s4    s5    s6    s7    s8    s9  ...  \
# fips                                                             ...
# 01001  12   7.0   6.0  11.0   9.0  23.0  42.0  45.0  61.0  43.0  ...
# 01003  29  37.0  43.0  38.0  34.0  35.0  38.0  19.0  10.0  21.0  ...
# 01005   2   7.0   9.0  14.0  11.0  15.0  21.0  26.0  45.0  40.0  ...
# 01007   4   9.0  13.0   8.0   8.0   3.0   5.0   8.0  14.0   5.0  ...
# 01009  10   2.0   8.0  11.0   9.0   4.0   1.0   4.0  12.0   9.0  ...
#
#        perc_65yrs  perc_minority  perc_black  perc_hispanic  perc_poverty  \
# fips
# 01001   -0.794106       0.512705    0.741329      -0.489703     -0.225017
# 01003    0.257409      -0.180113   -0.042334      -0.365711     -0.883379
# 01005   -0.012923       2.192825    2.685016      -0.379632      2.589482
# 01007   -0.647773       0.481481    0.821243      -0.504693      1.091708
# 01009   -0.221003      -0.699751   -0.532156      -0.011632     -0.323771
#
#        perc_urban_pop    income      risk  risk_flu  urban_risk
# fips
# 01001        0.535824  0.480936  0.984276  1.006875    0.666999
# 01003        0.526204  0.353735  1.225361  1.296454    0.817850
# 01005       -0.291414 -1.333023  0.221392  0.420657   -0.240836
# 01007       -0.310652 -0.483902  0.308118  0.436170   -0.249735
# 01009       -1.003223 -0.167862  0.566669  0.617627   -0.724261
#
# [5 rows x 41 columns]

# %%
rea_1015_1029 = np.array([65, 70, 52, 47, 65, 60, 64, 75, 85, 78, 59, 74, 74, 81])

# %% [markdown]
# ## GLM

# %%
cov_prefix = 'population+perc_65yrs+perc_minority+perc_black+perc_hispanic+perc_poverty+income+'
cov = cov_prefix + 'perc_urban_pop+risk_flu+urban_risk'

# %%
cors = []
for i in range(len(steps_)):
    cur = steps_[i]
    formula = f'{cur}~{cov}'

    # Model fitting
    model = smf.glm(
        formula=formula,
        data=df_z,
        family=sm.families.Poisson(sm.families.links.log())
    ).fit()
    print(f'{model.summary()}\n\n')
    
    prd = model.predict()
    cor = pd.DataFrame(
        data={'prd': prd, 'grd': df_z[cur].values}, 
        index=df.index).corr().loc['prd', 'grd']
    print(cor)
    cors.append(cor)
    
    df_z[cur + '_p'] = model.predict()
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                     s0   No. Observations:                 3094
# Model:                            GLM   Df Residuals:                     3083
# Model Family:                 Poisson   Df Model:                           10
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -2.1220e+05
# Date:                Mon, 02 Nov 2020   Deviance:                   4.1454e+05
# Time:                        01:08:13   Pearson chi2:                 7.18e+05
# No. Iterations:                     8
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          2.0954      0.007    280.927      0.000       2.081       2.110
# population         0.0449      0.000    105.212      0.000       0.044       0.046
# perc_65yrs         0.4824      0.002    196.115      0.000       0.478       0.487
# perc_minority     -0.0692      0.005    -14.793      0.000      -0.078      -0.060
# perc_black         0.4387      0.004    100.771      0.000       0.430       0.447
# perc_hispanic      0.0883      0.002     41.908      0.000       0.084       0.092
# perc_poverty       0.5168      0.004    125.707      0.000       0.509       0.525
# income             0.4837      0.002    198.276      0.000       0.479       0.488
# perc_urban_pop    -0.1875      0.011    -17.714      0.000      -0.208      -0.167
# risk_flu          -0.6744      0.012    -57.125      0.000      -0.698      -0.651
# urban_risk         2.3729      0.013    177.829      0.000       2.347       2.399
# ==================================================================================
#
#
# 0.6194292891266105
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                     s1   No. Observations:                 3094
# Model:                            GLM   Df Residuals:                     3083
# Model Family:                 Poisson   Df Model:                           10
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                   -inf
# Date:                Mon, 02 Nov 2020   Deviance:                   2.8040e+05
# Time:                        01:08:13   Pearson chi2:                 4.48e+05
# No. Iterations:                     8
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          2.0083      0.008    249.437      0.000       1.993       2.024
# population         0.0512      0.001    102.330      0.000       0.050       0.052
# perc_65yrs         0.4217      0.003    143.820      0.000       0.416       0.427
# perc_minority     -0.2123      0.006    -36.286      0.000      -0.224      -0.201
# perc_black         0.5804      0.005    107.603      0.000       0.570       0.591
# perc_hispanic      0.1154      0.002     46.961      0.000       0.111       0.120
# perc_poverty       0.4410      0.005     91.245      0.000       0.431       0.450
# income             0.4953      0.003    171.389      0.000       0.490       0.501
# perc_urban_pop    -0.1632      0.012    -13.563      0.000      -0.187      -0.140
# risk_flu          -0.4164      0.013    -32.143      0.000      -0.442      -0.391
# urban_risk         2.0227      0.015    135.720      0.000       1.993       2.052
# ==================================================================================
#
#
# 0.6599984827986037
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                     s2   No. Observations:                 3094
# Model:                            GLM   Df Residuals:                     3083
# Model Family:                 Poisson   Df Model:                           10
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                   -inf
# Date:                Mon, 02 Nov 2020   Deviance:                   2.7677e+05
# Time:                        01:08:13   Pearson chi2:                 4.97e+05
# No. Iterations:                     8
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          2.0958      0.008    263.578      0.000       2.080       2.111
# population         0.0529      0.001    104.241      0.000       0.052       0.054
# perc_65yrs         0.3574      0.003    115.242      0.000       0.351       0.364
# perc_minority     -0.1040      0.006    -17.352      0.000      -0.116      -0.092
# perc_black         0.4590      0.006     83.015      0.000       0.448       0.470
# perc_hispanic      0.1249      0.003     49.777      0.000       0.120       0.130
# perc_poverty       0.3861      0.005     77.573      0.000       0.376       0.396
# income             0.4220      0.003    139.074      0.000       0.416       0.428
# perc_urban_pop    -0.0342      0.012     -2.795      0.005      -0.058      -0.010
# risk_flu          -0.3116      0.013    -23.979      0.000      -0.337      -0.286
# urban_risk         1.7822      0.015    117.844      0.000       1.753       1.812
# ==================================================================================
#
#
# 0.6471352274062901
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                     s3   No. Observations:                 3094
# Model:                            GLM   Df Residuals:                     3083
# Model Family:                 Poisson   Df Model:                           10
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                   -inf
# Date:                Mon, 02 Nov 2020   Deviance:                   3.0654e+05
# Time:                        01:08:13   Pearson chi2:                 8.69e+05
# No. Iterations:                     8
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          2.4660      0.007    369.626      0.000       2.453       2.479
# population         0.0756      0.000    167.205      0.000       0.075       0.077
# perc_65yrs         0.2286      0.003     72.273      0.000       0.222       0.235
# perc_minority     -0.1309      0.006    -21.582      0.000      -0.143      -0.119
# perc_black         0.4247      0.006     76.084      0.000       0.414       0.436
# perc_hispanic      0.1053      0.003     42.056      0.000       0.100       0.110
# perc_poverty       0.2709      0.005     54.173      0.000       0.261       0.281
# income             0.3735      0.003    122.653      0.000       0.368       0.379
# perc_urban_pop     0.1074      0.011      9.862      0.000       0.086       0.129
# risk_flu          -0.2736      0.011    -23.808      0.000      -0.296      -0.251
# urban_risk         1.4537      0.014    106.919      0.000       1.427       1.480
# ==================================================================================
#
#
# 0.6813115928613384
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                     s4   No. Observations:                 3094
# Model:                            GLM   Df Residuals:                     3083
# Model Family:                 Poisson   Df Model:                           10
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                   -inf
# Date:                Mon, 02 Nov 2020   Deviance:                   2.6374e+05
# Time:                        01:08:13   Pearson chi2:                 1.12e+06
# No. Iterations:                     8
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept
# No. Iterations:                     8
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          2.5415      0.007    370.347      0.000       2.528       2.555
# population         0.0954      0.000    208.203      0.000       0.095       0.096
# perc_65yrs        -0.0236      0.004     -5.712      0.000      -0.032      -0.016
# perc_minority      0.2293      0.007     33.119      0.000       0.216       0.243
# perc_black         0.0684      0.006     10.648      0.000       0.056       0.081
# perc_hispanic      0.1929      0.003     70.801      0.000       0.188       0.198
# perc_poverty      -0.1741      0.006    -28.176      0.000      -0.186      -0.162
# income            -0.1426      0.004    -32.056      0.000      -0.151      -0.134
# perc_urban_pop     0.3548      0.012     28.490      0.000       0.330       0.379
# risk_flu           0.5088      0.012     42.372      0.000       0.485       0.532
# urban_risk         0.4479      0.015     29.779      0.000       0.418       0.477
# ==================================================================================
#
#
# 0.8869725476004271
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    s11   No. Observations:                 3094
# Model:                            GLM   Df Residuals:                     3083
# Model Family:                 Poisson   Df Model:                           10
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                   -inf
# Date:                Mon, 02 Nov 2020   Deviance:                   1.6795e+05
# Time:                        01:08:14   Pearson chi2:                 2.83e+05
# No. Iterations:                     8
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          2.6285      0.007    390.253      0.000       2.615       2.642
# population         0.0877      0.000    209.336      0.000       0.087       0.088
# perc_65yrs        -0.0021      0.004     -0.582      0.560      -0.009       0.005
# perc_minority      0.1606      0.007     23.071      0.000       0.147       0.174
# perc_black         0.0205      0.007      3.137      0.002       0.008       0.033
# perc_hispanic      0.2038      0.002     83.374      0.000       0.199       0.209
# perc_poverty      -0.3139      0.006    -52.620      0.000      -0.326      -0.302
# income            -0.3044      0.004    -69.055      0.000      -0.313      -0.296
# perc_urban_pop     0.2511      0.012     20.919      0.000       0.228       0.275
# risk_flu           0.6578      0.011     57.928      0.000       0.636       0.680
# urban_risk         0.5583      0.014     39.265      0.000       0.530       0.586
# ==================================================================================
#
#
# 0.7853981996886782
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    s12   No. Observations:                 3094
# Model:                            GLM   Df Residuals:                     3083
# Model Family:                 Poisson   Df Model:                           10
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                   -inf
# Date:                Mon, 02 Nov 2020   Deviance:                   2.4279e+05
# Time:                        01:08:14   Pearson chi2:                 3.29e+05
# No. Iterations:                     8
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          2.8642      0.006    475.863      0.000       2.852       2.876
# population         0.0848      0.000    237.500      0.000       0.084       0.086
# perc_65yrs         0.0147      0.003      4.743      0.000       0.009       0.021
# perc_minority      0.0506      0.006      7.826      0.000       0.038       0.063
# perc_black         0.1039      0.006     17.298      0.000       0.092       0.116
# perc_hispanic      0.2023      0.002     98.785      0.000       0.198       0.206
# perc_poverty      -0.3398      0.005    -66.636      0.000      -0.350      -0.330
# income            -0.3698      0.004    -95.012      0.000      -0.377      -0.362
# perc_urban_pop     0.1464      0.010     13.943      0.000       0.126       0.167
# risk_flu           0.6662      0.010     67.245      0.000       0.647       0.686
# urban_risk         0.7273      0.012     59.035      0.000       0.703       0.751
# ==================================================================================
#
#
# 0.8048332383485323
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    s13   No. Observations:                 3094
# Model:                            GLM   Df Residuals:                     3083
# Model Family:                 Poisson   Df Model:                           10
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                   -inf
# Date:                Mon, 02 Nov 2020   Deviance:                   2.4871e+05
# Time:                        01:08:14   Pearson chi2:                 3.78e+05
# No. Iterations:                     8
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          3.0472      0.006    552.588      0.000       3.036       3.058
# population         0.0709      0.000    211.134      0.000       0.070       0.072
# perc_65yrs         0.0809      0.003     31.156      0.000       0.076       0.086
# perc_minority      0.0607      0.006     10.548      0.000       0.049       0.072
# perc_black         0.1511      0.005     28.346      0.000       0.141       0.162
# perc_hispanic      0.2484      0.002    141.197      0.000       0.245       0.252
# perc_poverty      -0.4279      0.004    -95.483      0.000      -0.437      -0.419
# income            -0.4287      0.003   -123.884      0.000      -0.435      -0.422
# perc_urban_pop     0.1245      0.009     13.185      0.000       0.106       0.143
# risk_flu           0.7097      0.009     79.956      0.000       0.692       0.727
# urban_risk         0.7747      0.011     70.298      0.000       0.753       0.796
# ==================================================================================
#
#
# 0.7627895682367729
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    s14   No. Observations:                 3094
# Model:                            GLM   Df Residuals:                     3083
# Model Family:                 Poisson   Df Model:                           10
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                   -inf
# Date:                Mon, 02 Nov 2020   Deviance:                   2.7150e+05
# Time:                        01:08:14   Pearson chi2:                 3.78e+05
# No. Iterations:                     8
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          3.2916      0.005    687.729      0.000       3.282       3.301
# population         0.0797      0.000    278.178      0.000       0.079       0.080
# perc_65yrs         0.0355      0.002     14.611      0.000       0.031       0.040
# perc_minority      0.0844      0.005     16.334      0.000       0.074       0.095
# perc_black         0.1059      0.005     22.007      0.000       0.096       0.115
# perc_hispanic      0.2552      0.002    158.642      0.000       0.252       0.258
# perc_poverty      -0.4666      0.004   -113.244      0.000      -0.475      -0.458
# income            -0.4497      0.003   -141.357      0.000      -0.456      -0.444
# perc_urban_pop     0.0543      0.008      6.534      0.000       0.038       0.071
# risk_flu           0.6967      0.008     89.136      0.000       0.681       0.712
# urban_risk         0.7757      0.010     79.893      0.000       0.757       0.795
# ==================================================================================
#
#
# 0.8325377996814334
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    s15   No. Observations:                 3094
# Model:                            GLM   Df Residuals:                     3083
# Model Family:                 Poisson   Df Model:                           10
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                   -inf
# Date:                Mon, 02 Nov 2020   Deviance:                   2.8179e+05
# Time:                        01:08:14   Pearson chi2:                 3.84e+05
# No. Iterations:                     8
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          3.4769      0.004    813.393      0.000       3.468       3.485
# population         0.0758      0.000    269.860      0.000       0.075       0.076
# perc_65yrs         0.0843      0.002     38.478      0.000       0.080       0.089
# perc_minority     -0.0128      0.005     -2.498      0.012      -0.023      -0.003
# perc_black         0.2246      0.005     47.669      0.000       0.215       0.234
# perc_hispanic      0.2720      0.001    184.063      0.000       0.269       0.275
# perc_poverty      -0.4606      0.004   -120.985      0.000      -0.468      -0.453
# income            -0.4454      0.003   -148.631      0.000      -0.451      -0.440
# perc_urban_pop     0.0006      0.008      0.075      0.941      -0.014       0.015
# risk_flu           0.6793      0.007     96.723      0.000       0.666       0.693
# urban_risk         0.8235      0.009     93.979      0.000       0.806       0.841
# ==================================================================================
#
#
# 0.8614080908959936
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    s16   No. Observations:                 3094
# Model:                            GLM   Df Residuals:                     3083
# Model Family:                 Poisson   Df Model:                           10
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                   -inf
# Date:                Mon, 02 Nov 2020   Deviance:                   2.8077e+05
# Time:                        01:08:14   Pearson chi2:                 3.54e+05
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                   -inf
# Date:                Mon, 02 Nov 2020   Deviance:                   1.9202e+05
# Time:                        01:08:14   Pearson chi2:                 2.63e+05
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ...
# Intercept          3.5089      0.004    860.898      0.000       3.501       3.517
# population         0.0791      0.000    195.604      0.000       0.078       0.080
# perc_65yrs        -0.2434      0.003    -79.128      0.000      -0.249      -0.237
# perc_minority      0.1260      0.005     26.947      0.000       0.117       0.135
# perc_black        -0.1889      0.004    -43.045      0.000      -0.198      -0.180
# perc_hispanic     -0.0526      0.002    -26.508      0.000      -0.056      -0.049
# perc_poverty      -0.0159      0.004     -3.651      0.000      -0.024      -0.007
# income            -0.2239      0.003    -67.839      0.000      -0.230      -0.217
# perc_urban_pop     0.2221      0.008     27.948      0.000       0.207       0.238
# risk_flu           0.4503      0.007     60.513      0.000       0.436       0.465
# urban_risk         0.6021      0.010     62.125      0.000       0.583       0.621
# ==================================================================================
#
#
# 0.857655457221412
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    s23   No. Observations:                 3094
# Model:                            GLM   Df Residuals:                     3083
# Model Family:                 Poisson   Df Model:                           10
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                   -inf
# Date:                Mon, 02 Nov 2020   Deviance:                   1.5912e+05
# Time:                        01:08:15   Pearson chi2:                 1.50e+05
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          3.3651      0.004    771.793      0.000       3.357       3.374
# population         0.0813      0.000    170.735      0.000       0.080       0.082
# perc_65yrs        -0.3049      0.003    -89.415      0.000      -0.312      -0.298
# perc_minority      0.0615      0.005     11.707      0.000       0.051       0.072
# perc_black        -0.1601      0.005    -32.638      0.000      -0.170      -0.150
# perc_hispanic     -0.1463      0.002    -63.405      0.000      -0.151      -0.142
# perc_poverty      -0.0085      0.005     -1.787      0.074      -0.018       0.001
# income            -0.1827      0.004    -51.484      0.000      -0.190      -0.176
# perc_urban_pop     0.2522      0.009     29.362      0.000       0.235       0.269
# risk_flu           0.3866      0.008     48.033      0.000       0.371       0.402
# urban_risk         0.6069      0.011     57.477      0.000       0.586       0.628
# ==================================================================================
#
#
# 0.8741732323303331
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    s24   No. Observations:                 3094
# Model:                            GLM   Df Residuals:                     3083
# Model Family:                 Poisson   Df Model:                           10
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                   -inf
# Date:                Mon, 02 Nov 2020   Deviance:                   2.5173e+05
# Time:                        01:08:15   Pearson chi2:                 2.76e+05
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          3.6654      0.004   1006.438      0.000       3.658       3.673
# population         0.0868      0.000    204.914      0.000       0.086       0.088
# perc_65yrs        -0.3392      0.003   -109.160      0.000      -0.345      -0.333
# perc_minority     -0.0168      0.005     -3.254      0.001      -0.027      -0.007
# perc_black        -0.0722      0.005    -15.150      0.000      -0.082      -0.063
# perc_hispanic     -0.1298      0.002    -62.528      0.000      -0.134      -0.126
# perc_poverty      -0.0917      0.004    -20.946      0.000      -0.100      -0.083
# income            -0.2433      0.003    -72.507      0.000      -0.250      -0.237
# perc_urban_pop     0.1053      0.007     14.212      0.000       0.091       0.120
# risk_flu           0.3866      0.007     56.598      0.000       0.373       0.400
# urban_risk         0.6439      0.009     70.997      0.000       0.626       0.662
# ==================================================================================
#
#
# 0.8278933839912375
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    s25   No. Observations:                 3094
# Model:                            GLM   Df Residuals:                     3083
# Model Family:                 Poisson   Df Model:                           10
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                   -inf
# Date:                Mon, 02 Nov 2020   Deviance:                   1.9505e+05
# Time:                        01:08:15   Pearson chi2:                 2.87e+05
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          3.6995      0.003   1067.467      0.000       3.693       3.706
# population         0.0901      0.000    235.012      0.000       0.089       0.091
# perc_65yrs        -0.3979      0.003   -128.450      0.000      -0.404      -0.392
# perc_minority     -0.0343      0.005     -6.618      0.000      -0.044      -0.024
# perc_black        -0.1077      0.005    -22.160      0.000      -0.117      -0.098
# perc_hispanic     -0.0752      0.002    -37.936      0.000      -0.079      -0.071
# perc_poverty      -0.2244      0.004    -50.210      0.000      -0.233      -0.216
# income            -0.3304      0.003    -96.122      0.000      -0.337      -0.324
# perc_urban_pop    -0.0571      0.007     -8.176      0.000      -0.071      -0.043
# risk_flu           0.2361      0.007     36.058      0.000       0.223       0.249
# urban_risk         0.8562      0.009     99.440      0.000       0.839       0.873
# ==================================================================================
#
#
# 0.7164864502686047
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    s26   No. Observations:                 3094
# Model:                            GLM   Df Residuals:                     3083
# Model Family:                 Poisson   Df Model:                           10
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                   -inf
# Date:                Mon, 02 Nov 2020   Deviance:                   1.7749e+05
# Time:                        01:08:15   Pearson chi2:                 2.15e+05
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          3.7108      0.003   1087.062      0.000       3.704       3.717
# population         0.0820      0.000    196.480      0.000       0.081       0.083
# perc_65yrs        -0.3207      0.003   -107.445      0.000      -0.327      -0.315
# perc_minority      0.0351      0.005      7.218      0.000       0.026       0.045
# perc_black        -0.2423      0.005    -52.014      0.000      -0.251      -0.233
# perc_hispanic     -0.1313      0.002    -63.682      0.000      -0.135      -0.127
# perc_poverty      -0.2438      0.005    -53.292      0.000      -0.253      -0.235
# income            -0.3382      0.003    -99.270      0.000      -0.345      -0.331
# perc_urban_pop     0.0344      0.007      5.047      0.000       0.021       0.048
# risk_flu           0.0829      0.007     12.665      0.000       0.070       0.096
# urban_risk         0.9681      0.009    112.687      0.000       0.951       0.985
# ==================================================================================
#
#
# 0.8408555132809139
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    s27   No. Observations:                 3094
# Model:                            GLM   Df Residuals:                     3083
# Model Family:                 Poisson   Df Model:                           10
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                   -inf
# Date:                Mon, 02 Nov 2020   Deviance:                   1.6510e+05
# Time:                        01:08:15   Pearson chi2:                 2.01e+05
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          3.8715      0.003   1233.223      0.000       3.865       3.878
# population         0.0849      0.000    206.546      0.000       0.084       0.086
# perc_65yrs        -0.3319      0.003   -118.051      0.000      -0.337      -0.326
# perc_minority      0.0315      0.005      6.908      0.000       0.023       0.040
# perc_black        -0.2539      0.004    -58.118      0.000      -0.262      -0.245
# perc_hispanic     -0.1779      0.002    -88.782      0.000      -0.182      -0.174
# perc_poverty      -0.2513      0.004    -58.064      0.000      -0.260      -0.243
# income            -0.3579      0.003   -109.802      0.000      -0.364      -0.352
# perc_urban_pop     0.0914      0.006     14.452      0.000       0.079       0.104
# risk_flu           0.0825      0.006     13.595      0.000       0.071       0.094
# urban_risk         0.9086      0.008    113.018      0.000       0.893       0.924
# ==================================================================================
#
#
# 0.8628712607826083
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    s28   No. Observations:                 3094
# Model:                            GLM   Df Residuals:                     3083
# Model Family:                 Poisson   Df Model:                           10
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                   -inf
# Date:                Mon, 02 Nov 2020   Deviance:                   1.8693e+05
# Time:                        01:08:15   Pearson chi2:                 2.18e+05
# No. Iterations:                     6
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          4.0089      0.003   1367.773      0.000       4.003       4.015
# population         0.0807      0.000    205.291      0.000       0.080       0.081
# perc_65yrs        -0.2792      0.003   -109.164      0.000      -0.284      -0.274
# perc_minority     -0.0308      0.005     -6.616      0.000      -0.040      -0.022
# perc_black        -0.1749      0.004    -39.633      0.000      -0.184      -0.166
# perc_hispanic     -0.1534      0.002    -82.985      0.000      -0.157      -0.150
# perc_poverty      -0.3189      0.004    -77.373      0.000      -0.327      -0.311
# income            -0.3937      0.003   -127.104      0.000      -0.400      -0.388
# perc_urban_pop     0.0829      0.006     14.084      0.000       0.071       0.094
# risk_flu           0.0572      0.006     10.094      0.000       0.046       0.068
# urban_risk         0.9707      0.007    129.737      0.000       0.956       0.985
# ==================================================================================
#
#
# 0.8250598404940607
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    s29   No. Observations:                 3094
# Model:                            GLM   Df Residuals:                     3083
# Model Family:                 Poisson   Df Model:                           10
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                   -inf
# Date:                Mon, 02 Nov 2020   Deviance:                   2.3408e+05
# Time:                        01:08:15   Pearson chi2:                 3.09e+05
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          4.1645      0.003   1542.240      0.000       4.159       4.170
# population         0.0844      0.000    248.505      0.000       0.084       0.085
# perc_65yrs        -0.2940      0.002   -125.046      0.000      -0.299      -0.289
# perc_minority     -0.0589      0.004    -13.630      0.000      -0.067      -0.050
# perc_black        -0.1862      0.004    -45.312      0.000      -0.194      -0.178
# perc_hispanic     -0.1388      0.002    -83.655      0.000      -0.142      -0.136
# perc_poverty      -0.3108      0.004    -82.328      0.000      -0.318      -0.303
# income            -0.3998      0.003   -140.335      0.000      -0.405      -0.394
# perc_urban_pop     0.0567      0.005     10.601      0.000       0.046       0.067
# risk_flu          -0.0123      0.005     -2.355      0.019      -0.022      -0.002
# urban_risk         1.0557      0.007    154.582      0.000       1.042       1.069
# ==================================================================================
#
#
# 0.8247012401656063

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 6))
ax.plot(cors, marker='o')

# %% [markdown]
# ## Forcasting

# %% [markdown]
# ### make tensorflow regressor a little easier to use

# %%
class tfRegr:
    
    def __init__(self, 
                 epoch=100, 
                 verbose=False, 
                 validation_split=0.2, 
                 learning_rate=.1):
        
        self. normalizer = preprocessing.Normalization()
        self.ep = epoch
        self.vb = verbose
        self.vs = validation_split
        self.lr = learning_rate
    
    def fit(self, X, y):
        self.normalizer.adapt(X)

        self.model = tf.keras.Sequential([
            self.normalizer,
            layers.Dense(units=1)
        ])

        self.model.compile(
            optimizer=tf.optimizers.Adam(learning_rate=self.lr),
            loss='mean_absolute_error'
        )

        self.history = self.model.fit(
            X, y,
            epochs=self.ep,
            verbose=self.vb, # logging
            validation_split=self.vs # Calculate validation results on a fraction of the training data
        )
        return self.model

# %%
df_data = df_z[[f's{i}' for i in range(len(steps_))] + [f's{i}_p' for i in range(len(steps_))]].copy()
regrs = {
    'RF': RandomForestRegressor(min_samples_split=2), 
    'ET': ExtraTreesRegressor(min_samples_split=2), 
    'TF': tfRegr(),
}
r2s_nxt_1 = {regr_name: [] for regr_name in regrs}
r2s_nxt_2 = {regr_name: [] for regr_name in regrs}

# %%
for i in range(1, len(steps_)):

    cur_idx = int(steps_[i][1:])
    prv, cur = steps_[i - 1], steps_[i] 
    nxt_1, nxt_2 = f's{cur_idx + 1}', f's{cur_idx + 2}'
    
    print(f'{steps[i]}:')
    
    # Training regressor
    X_train = df_data[[prv, cur + '_p']].values
    y_train = df_data[cur].values
        
    for regr_name, regr in regrs.items():
        regr = regr.fit(X_train, y_train)
    
        # Predicting next 1 step
        X_nxt_1 = df_data[[cur, cur + '_p']].values
        y_nxt_1 = regr.predict(X_nxt_1)
        
        df_data[cur + f'_1p{regr_name}'] = y_nxt_1
        sum_nxt_1 = y_nxt_1.sum()
        
        # Predicting next 2 step
        X_nxt_2 = df_data[[cur + f'_1p{regr_name}', cur + '_p']].values
        y_nxt_2 = regr.predict(X_nxt_2)
        
        df_data[cur + f'_2p{regr_name}'] = y_nxt_2
        sum_nxt_2 = y_nxt_2.sum()
        
        # evaluating and showing results
        if i < len(steps_) - 1:
            y_test = df_data[nxt_1].values
            r2 = r2_score(y_test, y_nxt_1)
            r2s_nxt_1[regr_name].append(r2)
            sum_grd = y_test.sum()
            print(f'\t{regr_name}, next 1: sum = {sum_grd:.0f}, predicted sum = {sum_nxt_1:.0f}, r2 = {r2: .3f}')
            
            if i < len(steps_) - 2:
                y_test = df_data[nxt_2].values
                r2 = r2_score(y_test, y_nxt_2)
                r2s_nxt_2[regr_name].append(r2)
                sum_grd = y_test.sum()
                print(f'\t{regr_name}, next 2: sum = {sum_grd:.0f}, predicted sum = {sum_nxt_2:.0f}, r2 = {r2: .3f}')
            else:
                print(f'\t{regr_name}, next 2: predicted sum = {sum_nxt_2:.0f}')
        else:
            print(f'\t{regr_name}, next 1: predicted sum = {sum_nxt_1:.0f}')
            print(f'\t{regr_name}, next 2: predicted sum = {sum_nxt_2:.0f}')
# Out:
# 4-11:
# 	RF, next 1: sum = 202912, predicted sum = 170697, r2 =  0.901
# 	RF, next 2: sum = 206731, predicted sum = 142322, r2 =  0.776
# 	ET, next 1: sum = 202912, predicted sum = 174209, r2 =  0.888
# 	ET, next 2: sum = 206731, predicted sum = 148126, r2 =  0.780
# /usr/local/lib64/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/lib64/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 	TF, next 1: sum = 202912, predicted sum = 151842, r2 =  0.818
# 	TF, next 2: sum = 206731, predicted sum = 121218, r2 =  0.613
# 4-18:
# 	RF, next 1: sum = 206731, predicted sum = 195328, r2 =  0.909
# 	RF, next 2: sum = 192584, predicted sum = 187557, r2 =  0.724
# 	ET, next 1: sum = 206731, predicted sum = 192972, r2 =  0.892
# 	ET, next 2: sum = 192584, predicted sum = 190933, r2 =  0.705
# 	TF, next 1: sum = 206731, predicted sum = 173122, r2 =  0.904
# 	TF, next 2: sum = 192584, predicted sum = 151883, r2 =  0.776
# 4-25:
# 	RF, next 1: sum = 192584, predicted sum = 214425, r2 =  0.862
# 	RF, next 2: sum = 175327, predicted sum = 219458, r2 =  0.689
# 	ET, next 1: sum = 192584, predicted sum = 217218, r2 =  0.842
# 	ET, next 2: sum = 175327, predicted sum = 227024, r2 =  0.647
# 	TF, next 1: sum = 192584, predicted sum = 192411, r2 =  0.893
# 	TF, next 2: sum = 175327, predicted sum = 181269, r2 =  0.775
# 5-2:
# 	RF, next 1: sum = 175327, predicted sum = 182607, r2 =  0.931
# 	RF, next 2: sum = 156433, predicted sum = 184271, r2 =  0.897
# 	ET, next 1: sum = 175327, predicted sum = 181679, r2 =  0.947
# 	ET, next 2: sum = 156433, predicted sum = 183312, r2 =  0.852
# 	TF, next 1: sum = 175327, predicted sum = 154107, r2 =  0.916
# 	TF, next 2: sum = 156433, predicted sum = 127833, r2 =  0.856
# 5-9:
# 	RF, next 1: sum = 156433, predicted sum = 167727, r2 =  0.935
# 	RF, next 2: sum = 151483, predicted sum = 162907, r2 =  0.928
# 	ET, next 1: sum = 156433, predicted sum = 166801, r2 =  0.919
# 	ET, next 2: sum = 151483, predicted sum = 167000, r2 =  0.893
# 	TF, next 1: sum = 156433, predicted sum = 148026, r2 =  0.945
# 	TF, next 2: sum = 151483, predicted sum = 128943, r2 =  0.901
# 5-16:
# 	RF, next 1: sum = 151483, predicted sum = 141013, r2 =  0.857
# 	RF, next 2: sum = 145924, predicted sum = 133627, r2 =  0.704
# 	ET, next 1: sum = 151483, predicted sum = 144607, r2 =  0.935
# 	ET, next 2: sum = 145924, predicted sum = 135087, r2 =  0.847
# 	TF, next 1: sum = 151483, predicted sum = 131222, r2 =  0.944
# 	TF, next 2: sum = 145924, predicted sum = 112790, r2 =  0.841
# 5-23:
# 	RF, next 1: sum = 145924, predicted sum = 153710, r2 =  0.903
# 	RF, next 2: sum = 141941, predicted sum = 155169, r2 =  0.768
# 	ET, next 1: sum = 145924, predicted sum = 153241, r2 =  0.892
# 	ET, next 2: sum = 141941, predicted sum = 153781, r2 =  0.716
# 	TF, next 1: sum = 145924, predicted sum = 144130, r2 =  0.927
# 	TF, next 2: sum = 141941, predicted sum = 138248, r2 =  0.862
# 5-30:
# 	RF, next 1: sum = 141941, predicted sum = 142631, r2 =  0.901
# 	RF, next 2: sum = 145912, predicted sum = 143224, r2 =  0.716
# 	ET, next 1: sum = 141941, predicted sum = 141484, r2 =  0.908
# 	ET, next 2: sum = 145912, predicted sum = 140122, r2 =  0.763
# 	TF, next 1: sum = 141941, predicted sum = 131205, r2 =  0.924
# 	TF, next 2: sum = 145912, predicted sum = 121448, r2 =  0.797
# 6-6:
# 	RF, next 1: sum = 145912, predicted sum = 135779, r2 =  0.834
# 	RF, next 2: sum = 177533, predicted sum = 131295, r2 =  0.579
# 	ET, next 1: sum = 145912, predicted sum = 139699, r2 =  0.875
# 	ET, next 2: sum = 177533, predicted sum = 136620, r2 =  0.643
# 	TF, next 1: sum = 145912, predicted sum = 120345, r2 =  0.875
# 	TF, next 2: sum = 177533, predicted sum = 105427, r2 =  0.596
# 6-13:
# 	RF, next 1: sum = 177533, predicted sum = 148403, r2 =  0.775
# 	RF, next 2: sum = 251443, predicted sum = 152839, r2 =  0.611
# 	ET, next 1: sum = 177533, predicted sum = 150082, r2 =  0.795
# 	ET, next 2: sum = 251443, predicted sum = 153294, r2 =  0.658
# 	TF, next 1: sum = 177533, predicted sum = 135255, r2 =  0.780
# 	TF, next 2: sum = 251443, predicted sum = 127791, r2 =  0.575
# 6-20:
# 	RF, next 1: sum = 251443, predicted sum = 210732, r2 =  0.892
# 	RF, next 2: sum = 326205, predicted sum = 235855, r2 =  0.737
# 	ET, next 1: sum = 251443, predicted sum = 205544, r2 =  0.904
# 	ET, next 2: sum = 326205, predicted sum = 231257, r2 =  0.822
# 	TF, next 1: sum = 251443, predicted sum = 165045, r2 =  0.820
# 	TF, next 2: sum = 326205, predicted sum = 155475, r2 =  0.611
# 6-27:
# 	RF, next 1: sum = 326205, predicted sum = 316187, r2 =  0.858
# 	RF, next 2: sum = 397010, predicted sum = 392174, r2 =  0.749
# 	ET, next 1: sum = 326205, predicted sum = 326221, r2 =  0.911
# 	ET, next 2: sum = 397010, predicted sum = 415392, r2 =  0.827
# 	TF, next 1: sum = 326205, predicted sum = 289157, r2 =  0.882
# 	TF, next 2: sum = 397010, predicted sum = 324054, r2 =  0.872
# 7-4:
# 	RF, next 1: sum = 397010, predicted sum = 411377, r2 =  0.916
# 	RF, next 2: sum = 455736, predicted sum = 495381, r2 =  0.901
# 	ET, next 1: sum = 397010, predicted sum = 417072, r2 =  0.836
# 	ET, next 2: sum = 455736, predicted sum = 513238, r2 =  0.779
# 	TF, next 1: sum = 397010, predicted sum = 342091, r2 =  0.911
# 	TF, next 2: sum = 455736, predicted sum = 354248, r2 =  0.874
# 7-11:
# 	RF, next 1: sum = 455736, predicted sum = 441250, r2 =  0.937
# 	RF, next 2: sum = 455720, predicted sum = 480088, r2 =  0.911
# 	ET, next 1: sum = 455736, predicted sum = 453305, r2 =  0.950
# 	ET, next 2: sum = 455720, predicted sum = 495314, r2 =  0.891
# 	TF, next 1: sum = 455736, predicted sum = 421189, r2 =  0.934
# 	TF, next 2: sum = 455720, predicted sum = 439009, r2 =  0.833
# 7-18:
# 	RF, next 1: sum = 455720, predicted sum = 490055, r2 =  0.936
# 	RF, next 2: sum = 431892, predicted sum = 531038, r2 =  0.868
# 	ET, next 1: sum = 455720, predicted sum = 504276, r2 =  0.918
# 	ET, next 2: sum = 431892, predicted sum = 557150, r2 =  0.803
# 	TF, next 1: sum = 455720, predicted sum = 421965, r2 =  0.920
# 	TF, next 2: sum = 431892, predicted sum = 402785, r2 =  0.860
# 7-25:
# 	RF, next 1: sum = 431892, predicted sum = 464280, r2 =  0.969
# 	RF, next 2: sum = 368080, predicted sum = 464671, r2 =  0.770
# 	ET, next 1: sum = 431892, predicted sum = 460124, r2 =  0.963
# 	ET, next 2: sum = 368080, predicted sum = 468886, r2 =  0.691
# 	TF, next 1: sum = 431892, predicted sum = 419240, r2 =  0.938
# 	TF, next 2: sum = 368080, predicted sum = 399859, r2 =  0.855
# 8-1:
# 	RF, next 1: sum = 368080, predicted sum = 416709, r2 =  0.851
# 	RF, next 2: sum = 356022, predicted sum = 409234, r2 =  0.815
# 	ET, next 1: sum = 368080, predicted sum = 416726, r2 =  0.820
# 	ET, next 2: sum = 356022, predicted sum = 406686, r2 =  0.819
# 	TF, next 1: sum = 368080, predicted sum = 386539, r2 =  0.907
# 	TF, next 2: sum = 356022, predicted sum = 361430, r2 =  0.833
# 8-8:
# 	RF, next 1: sum = 356022, predicted sum = 332069, r2 =  0.876
# 	RF, next 2: sum = 300002, predicted sum = 314135, r2 =  0.825
# 	ET, next 1: sum = 356022, predicted sum = 328786, r2 =  0.858
# 	ET, next 2: sum = 300002, predicted sum = 307845, r2 =  0.780
# 	TF, next 1: sum = 356022, predicted sum = 298448, r2 =  0.844
# 	TF, next 2: sum = 300002, predicted sum = 265579, r2 =  0.760
# 8-15:
# 	RF, next 1: sum = 300002, predicted sum = 352675, r2 =  0.781
# 	RF, next 2: sum = 284166, predicted sum = 352787, r2 =  0.569
# 	ET, next 1: sum = 300002, predicted sum = 354275, r2 =  0.677
# 	ET, next 2: sum = 284166, predicted sum = 353278, r2 =  0.394
# 	TF, next 1: sum = 300002, predicted sum = 317064, r2 =  0.832
# 	TF, next 2: sum = 284166, predicted sum = 292865, r2 =  0.818
# 8-22:
# 	RF, next 1: sum = 284166, predicted sum = 274547, r2 =  0.873
# 	RF, next 2: sum = 282511, predicted sum = 258029, r2 =  0.741
# 	ET, next 1: sum = 284166, predicted sum = 263290, r2 =  0.898
# 	ET, next 2: sum = 282511, predicted sum = 242160, r2 =  0.838
# 	TF, next 1: sum = 284166, predicted sum = 241948, r2 =  0.903
# 	TF, next 2: sum = 282511, predicted sum = 210773, r2 =  0.826
# 8-29:
# 	RF, next 1: sum = 282511, predicted sum = 281030, r2 =  0.870
# 	RF, next 2: sum = 235011, predicted sum = 281957, r2 =  0.687
# 	ET, next 1: sum = 282511, predicted sum = 284416, r2 =  0.868
# 	ET, next 2: sum = 235011, predicted sum = 287960, r2 =  0.587
# 	TF, next 1: sum = 282511, predicted sum = 249823, r2 =  0.893
# 	TF, next 2: sum = 235011, predicted sum = 227357, r2 =  0.807
# 9-5:
# 	RF, next 1: sum = 235011, predicted sum = 282731, r2 =  0.823
# 	RF, next 2: sum = 288955, predicted sum = 288346, r2 =  0.761
# 	ET, next 1: sum = 235011, predicted sum = 284945, r2 =  0.759
# 	ET, next 2: sum = 288955, predicted sum = 285868, r2 =  0.786
# 	TF, next 1: sum = 235011, predicted sum = 267483, r2 =  0.836
# 	TF, next 2: sum = 288955, predicted sum = 255821, r2 =  0.815
# 9-12:
# 	RF, next 1: sum = 288955, predicted sum = 207843, r2 =  0.687
# 	RF, next 2: sum = 298956, predicted sum = 196296, r2 =  0.363
# 	ET, next 1: sum = 288955, predicted sum = 214583, r2 =  0.757
# 	ET, next 2: sum = 298956, predicted sum = 203584, r2 =  0.494
# 	TF, next 1: sum = 288955, predicted sum = 189152, r2 =  0.730
# 	TF, next 2: sum = 298956, predicted sum = 161613, r2 =  0.423
# 9-19:
# 	RF, next 1: sum = 298956, predicted sum = 331064, r2 =  0.689
# 	RF, next 2: sum = 293805, predicted sum = 368305, r2 =  0.798
# 	ET, next 1: sum = 298956, predicted sum = 332175, r2 =  0.713
# 	ET, next 2: sum = 293805, predicted sum = 364482, r2 =  0.789
# 	TF, next 1: sum = 298956, predicted sum = 300681, r2 =  0.757
# 	TF, next 2: sum = 293805, predicted sum = 311194, r2 =  0.860
# 9-26:
# 	RF, next 1: sum = 293805, predicted sum = 296619, r2 =  0.755
# 	RF, next 2: sum = 328692, predicted sum = 301559, r2 =  0.453
# 	ET, next 1: sum = 293805, predicted sum = 303591, r2 =  0.391
# 	ET, next 2: sum = 328692, predicted sum = 306915, r2 = -0.056
# 	TF, next 1: sum = 293805, predicted sum = 275971, r2 =  0.657
# 	TF, next 2: sum = 328692, predicted sum = 258449, r2 =  0.568
# 10-3:
# 	RF, next 1: sum = 328692, predicted sum = 295232, r2 =  0.889
# 	RF, next 2: sum = 380890, predicted sum = 301157, r2 =  0.804
# 	ET, next 1: sum = 328692, predicted sum = 299681, r2 =  0.876
# 	ET, next 2: sum = 380890, predicted sum = 307062, r2 =  0.809
# 	TF, next 1: sum = 328692, predicted sum = 279918, r2 =  0.889
# 	TF, next 2: sum = 380890, predicted sum = 269722, r2 =  0.769
# 10-10:
# 	RF, next 1: sum = 380890, predicted sum = 359809, r2 =  0.890
# 	RF, next 2: sum = 456580, predicted sum = 390118, r2 =  0.776
# 	ET, next 1: sum = 380890, predicted sum = 360284, r2 =  0.871
# 	ET, next 2: sum = 456580, predicted sum = 387163, r2 =  0.780
# 	TF, next 1: sum = 380890, predicted sum = 350210, r2 =  0.910
# 	TF, next 2: sum = 456580, predicted sum = 369128, r2 =  0.822
# 10-17:
# 	RF, next 1: sum = 456580, predicted sum = 423663, r2 =  0.881
# 	RF, next 2: predicted sum = 458074
# 	ET, next 1: sum = 456580, predicted sum = 424531, r2 =  0.902
# 	ET, next 2: predicted sum = 471809
# 	TF, next 1: sum = 456580, predicted sum = 416484, r2 =  0.917
# 	TF, next 2: predicted sum = 448296
# 10-24:
# 	RF, next 1: predicted sum = 535789
# 	RF, next 2: predicted sum = 621137
# 	ET, next 1: predicted sum = 533175
# 	ET, next 2: predicted sum = 608035
# 	TF, next 1: predicted sum = 501901
# 	TF, next 2: predicted sum = 543145

# %%
print('next 1 week')
for regr_name, r2_arr in r2s_nxt_1.items():
    r2_arr = np.array(r2_arr)
    print(f'\t{regr_name}: {r2_arr.mean(): .3f}')

print('next 2 week')
for regr_name, r2_arr in r2s_nxt_2.items():    
    r2_arr = np.array(r2_arr)
    print(f'\t{regr_name}: {r2_arr.mean(): .3f}')
# Out:
# next 1 week
# 	RF:  0.864
# 	ET:  0.849
# 	TF:  0.872
# next 2 week
# 	RF:  0.738
# 	ET:  0.716
# 	TF:  0.770

# %%
srs = []
grd = df_data[[f's{i}' for i in range(len(steps_))]].sum()
grd.name = 'grd'
srs.append(grd)

for key in regrs:
    cols = [x for x in df_data.columns if x.endswith(f'_1p{key}')]
    sr = df_data[cols].sum().astype(int)
    sr.index = [x[:-5] for x in sr.index]
    sr.name = key + '1'
    srs.append(sr)
    
    cols = [x for x in df_data.columns if x.endswith(f'_2p{key}')]
    sr = df_data[cols].sum().astype(int)
    sr.index = [x[:-5] for x in sr.index]
    sr.name = key + '2'
    srs.append(sr)

df_count = pd.concat(srs, join='outer', axis=1)
df_count.index = [int(s[1:]) for s in df_count.index]
df_count.sort_index(inplace=True)

grd1 = df_count['grd'][2: ]
grd1.index = range(1, len(grd1) + 1)
grd1.name = 'grd1'
# print(grd1)

grd2 = df_count['grd'][3: ]
grd2.index = range(1, len(grd2) + 1)
grd2.name = 'grd2'
# print(grd2)

df_count = df_count.join(grd1, how='outer').join(grd2, how='outer')
df_count.index = steps
df_count.drop(steps[0], inplace=True)
df_count['avg1'] = df_count[[f'{key}1' for key in regrs]].mean(axis=1).astype(int)
df_count['avg2'] = df_count[[f'{key}2' for key in regrs]].mean(axis=1).astype(int)

# %%
df_count.to_csv('forecast_ours_1.csv', float_format='%0.f')

# %%
xtl1 = list(df_count.index[1:].values) + [next_1]
xtl2 = list(df_count.index[2:].values) + [next_1, next_2]
xtls = [xtl1, xtl2]

# %%
ylim = np.array([np.nanmin(df_count.values), np.nanmax(df_count.values)])
margin = (ylim[1] - ylim[0]) * .05
ylim = [ylim[0] - margin, ylim[1] + margin]

fig, axes = plt.subplots(2, 1, figsize=(18, 12))
xtl = df_count.index[1:] + ['10-31']
for i in [1, 2]:
    ax = axes[i - 1]
    xtl = xtls[i - 1]
    df_count[[f'grd{i}']].plot(ax=ax, marker='o')
    df_count[[f'avg{i}']].plot(ax=ax, marker='o')
    for method in regrs:
        tmp_df = df_count[[f'{method}{i}']]
        tmp_df.plot(ax=ax, marker='o')
        
    ax.set_ylim(ylim)
    ax.set_xticks(range(len(xtl)))
    ax.set_xticklabels(xtl, rotation=45, ha='center')
    
    ax.ticklabel_format(axis='y', style='sci', scilimits=(0, 0))
    ax.tick_params(axis='both', labelsize=15)
    ax.legend(prop=dict(size=14))

# %%
df_count_cumul = df_count.cumsum(axis=0)
ylim = np.array([np.nanmin(df_count_cumul.values), np.nanmax(df_count_cumul.values)])
margin = (ylim[1] - ylim[0]) * .05
ylim = [ylim[0] - margin, ylim[1] + margin]

fig, axes = plt.subplots(2, 1, figsize=(18, 12))

for i in [1, 2]:
    ax = axes[i - 1]
    xtl = xtls[i - 1]
    df_count_cumul[[f'grd{i}']].plot(ax=ax, marker='o')
    df_count_cumul[[f'avg{i}']].plot(ax=ax, marker='o')
    for method in regrs:
        tmp_df = df_count_cumul[[f'{method}{i}']]
        tmp_df.plot(ax=ax, marker='o')
    
    ax.set_ylim(ylim)
    
    ax.set_xticks(range(len(xtl)))
    ax.set_xticklabels(xtl, rotation=45, ha='center')
    
    ax.ticklabel_format(axis='y', style='sci', scilimits=(0, 0))
    ax.tick_params(axis='both', labelsize=15)
    ax.legend(prop=dict(size=14))

# %% [markdown]
# # Ignore below

# %% [markdown]
# ## autoregression

# %% [raw]
# def plot(df_data, k):
#     grd = df_data[[f's{i}' for i in range(15)]].sum().values
#
#     data = {'grd': grd[k + 1:].astype(int)}
#     for key in regrs:
#         vec = df_data[[f's{i}_p{key}' for i in range(k + 1, 15)]].sum()
#         # print(vec)
#         regr_name = vec.index[0].split('_')[1][1:]
#         vec.index = [x.split('_')[0] for x in vec.index]
#         data[regr_name] = vec.values.astype(int)
#     data = pd.DataFrame(data=data, index=range(k + 1, 15))
#     for i in range(k + 1):
#         data.loc[i, :] = grd[i]
#
#     data.sort_index(inplace=True)
#     data_cumul = data.cumsum(axis=0)
#
#     fig, axes = plt.subplots(2, 1, figsize=(12, 8))
#
#     ax = axes[0]
#     data.plot(ax=ax, marker='o')
#     ax.set_xticks(range(len(steps)))
#     ax.set_xticklabels(steps, rotation=45, ha='center')
#     ax.ticklabel_format(axis='y', style='sci', scilimits=(0, 0))
#     ax.tick_params(axis='both', labelsize=15)
#     ax.legend(prop=dict(size=14))
#
#     ax = axes[1]
#     data_cumul.plot(ax=ax, marker='o')
#     ax.set_xticks(range(len(steps)))
#     ax.set_xticklabels(steps, rotation=45, ha='center')
#     ax.ticklabel_format(axis='y', style='sci', scilimits=(0, 0))
#     ax.tick_params(axis='both', labelsize=15)
#     ax.legend(prop=dict(size=14))

# %% [raw]
# k = 2
# for i in range(k, len(steps_)):
#
#     if i < len(steps_) - 1:
#         nxt = steps_[i + 1]
#
#     print(f'{steps[i]}:')
#
#     # Training regressor
#     print(steps_[i - k : i] + [steps_[i] + '_p'])
#     X_train = df_data[steps_[i - k : i] + [steps_[i] + '_p']].values
#     y_train = df_data[steps_[i]].values
#
#     for regr_name, regr in regrs.items():
#         regr = regr.fit(X_train, y_train)
#
#         # Predicting and performance evaluation
#         X_test = df_data[steps_[i - k + 1 : i + 1] + [steps_[i] + '_p']].values
#         y_pred = regr.predict(X_test)
#
#         sum_prd = y_pred.sum()
#
#         if i < len(steps_) - 1:
#             y_test = df_data[nxt].values
#             r2 = r2_score(y_test, y_pred)
#             r2s[regr_name].append(r2)
#             df_data[nxt + f'_p{regr_name}'] = y_pred
#             sum_grd = y_test.sum()
#             print(f'\t{regr_name}, sum = {sum_grd}, predicted sum = {sum_prd:.0f}, r2 = {r2: .3f}')
#         else:
#             print(f'\t{regr_name}, predicted sum = {sum_prd:.3f}')

# %% [raw]
# for regr_name, r2_arr in r2s.items():
#     r2_arr = np.array(r2_arr)
#     print(f'{regr_name}: {r2_arr.mean(): .3}')

# %% [raw]
# plot(df_data, k)
